# %%
# !pip install langchain
# !pip install langchain-huggingface
# !pip install text-generation
# !pip install transformers
# !pip install sentencepiece
# !pip install accelerate
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 3.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 64.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 54.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 39.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 6.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 14.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 6.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 82.7 MB/s eta 0:00:00
# ...
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
# ...

# %%
import getpass
import os
os.environ['HUGGINGFACEHUB_API_TOKEN'] = getpass.getpass('HUGGINGFACEHUB_API_TOKEN:')
# Out:
# HUGGINGFACEHUB_API_TOKEN:··········

# %% [markdown]
# # we can instantiate ChatHuggingface model in two different ways :
# 1. HuggingfaceEndpoint
# 2. HuggingFacePipeline

# %%
# Model Using HuggingfaceEndpoint

from langchain_huggingface import HuggingFaceEndpoint, ChatHuggingFace

llm = HuggingFaceEndpoint(
    repo_id = 'mistralai/Mistral-7B-Instruct-v0.3',
    task = 'text-generation',
    max_new_tokens = 512,
    do_sample = False,
)

chat_model = ChatHuggingFace(llm = llm)
# Out:
# tokenizer_config.json:   0%|          | 0.00/141k [00:00<?, ?B/s]
# tokenizer.model:   0%|          | 0.00/587k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.96M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/414 [00:00<?, ?B/s]

# %%
from langchain_core.messages import (
    HumanMessage,
    SystemMessage,
)

message = [
    SystemMessage(content = 'You are helpful assistant'),
    HumanMessage(content = 'What is the meaning of life?'),
]

response = chat_model.invoke(message)
print(response)
#response
# Out:
# content="While I'm an AI and don't have personal beliefs or experiences, I can share that quests for the meaning of life have occupied philosophers, scientists, and theologians for centuries. Many theories have been proposed, including purposeful creation (theistic interpretations), survival and reproduction (biological or evolutionary arguments), self-discovery and personal growth (existentialism), or service to others (moral and altruistic perspectives).\n\nUltimately, the purpose or meaning of life might be a deeply personal question and may vary greatly among individuals. Some find meaning in personal connections, accomplishments, understanding, or through philosophical and spiritual belief systems. If you'd like to discuss a specific theory in more detail, feel free to ask!" additional_kwargs={} response_metadata={'token_usage': ChatCompletionOutputUsage(completion_tokens=162, prompt_tokens=16, total_tokens=178), 'model': '', 'finish_reason': 'stop'} id='run-f30377a3-0b5b-4119-8
# ...
